# %%
import getdist.plots as gplot
g = gplot.getSinglePlotter(chain_dir=r'./PLA')

samples = g.sample_analyser.samples_for_root('Datasets/Planck18/base/plikHM_TTTEEE_lowl_lowE_lensing/base_plikHM_TTTEEE_lowl_lowE_lensing_1')
p = samples.getParams()

derived = p.sigma8 * p.omegam ** 0.6
# Out:
# ---------------------------------------------------------------------------
# GetDistPlotError                          Traceback (most recent call last)
# <ipython-input-1-7ba454ab58b2> in <module>
#       2 g = gplot.getSinglePlotter(chain_dir=r'./PLA')
#       3
# ----> 4 samples = g.sample_analyser.samples_for_root('Datasets/Planck18/base/plikHM_TTTEEE_lowl_lowE_lensing/base_plikHM_TTTEEE_lowl_lowE_lensing_1')
#       5 p = samples.getParams()
#       6
#
# ~/anaconda2/envs/py3/lib/python3.7/site-packages/getdist/plots.py in samples_for_root(self, root, file_root, cache, settings)
#     498                         break
#     499         if not file_root:
# --> 500             raise GetDistPlotError('chain not found: ' + root)
#     501         if not self.chain_settings_have_priority:
#     502             dist_settings.update(self.ini.params)
#
# GetDistPlotError: chain not found: Datasets/Planck18/base/plikHM_TTTEEE_lowl_lowE_lensing/base_plikHM_TTTEEE_lowl_lowE_lensing_1

# %%
from getdist import MCSamples, plots
import getdist
samples = MCSamples(root='Datasets/Planck18/base/plikHM_TTTEEE_lowl_lowE_lensing/base_plikHM_TTTEEE_lowl_lowE_lensing_1', paramNamesFile='Datasets/Planck18/base/plikHM_TTTEEE_lowl_lowE_lensing/base_plikHM_TTTEEE_lowl_lowE_lensing.paramnames')
samples2=MCSamples(root='Datasets/Planck18/base/plikHM_TTTEEE_lowl_lowE_lensing/base_plikHM_TTTEEE_lowl_lowE_lensing_2', paramNamesFile='Datasets/Planck18/base/plikHM_TTTEEE_lowl_lowE_lensing/base_plikHM_TTTEEE_lowl_lowE_lensing.paramnames')

# %%
# Show plots inline, and load main getdist plot module and samples class
from __future__ import print_function
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import sys, os
sys.path.insert(0,os.path.realpath(os.path.join(os.getcwd(),'..')))
from getdist import plots, MCSamples
import getdist
# use this *after* importing getdist if you want to use interactive plots
# %matplotlib notebook
import matplotlib.pyplot as plt
import IPython
print('GetDist Version: %s, Matplotlib version: %s'%(getdist.__version__, plt.matplotlib.__version__))
# matplotlib 2 may not work very well without usetex on, can uncomment
# plt.rcParams['text.usetex']=True
# Out:
# GetDist Version: 1.0.3, Matplotlib version: 3.1.2

# %%
#Planck

g=plots.get_single_plotter(chain_dir=r'/home/nayantara/Desktop/Cosmology_Dvorkin/Project_Cosmology/Datasets/Combined chains/chains_FL2')
roots = ['base_plikHM_TTTEEE_lowl_lowE_lensing']
pairs = [['omegam', 'H0']]
g.plots_2d(roots, param_pairs=pairs, filled=True, shaded=False)
g.export()

# %%
analysis_settings = {'ignore_rows': '0.2'}
g=plots.get_single_plotter(chain_dir=r'/home/nayantara/Desktop/Cosmology_Dvorkin/Project_Cosmology/Datasets/Combined chains/chains_FL2/new',analysis_settings=analysis_settings)
roots = ['chfinal']
pairs = [['omegam', 'H0']]
g.plots_2d(roots, param_pairs=pairs, filled=True, shaded=False)
g.export()
# Out:
# /home/nayantara/Desktop/Cosmology_Dvorkin/Project_Cosmology/Datasets/Combined chains/chains_FL2/new/chfinal_1.txt
# /home/nayantara/Desktop/Cosmology_Dvorkin/Project_Cosmology/Datasets/Combined chains/chains_FL2/new/chfinal_2.txt
# /home/nayantara/Desktop/Cosmology_Dvorkin/Project_Cosmology/Datasets/Combined chains/chains_FL2/new/chfinal_3.txt
# /home/nayantara/Desktop/Cosmology_Dvorkin/Project_Cosmology/Datasets/Combined chains/chains_FL2/new/chfinal_4.txt
# Removed 0.2 as burn in
# ---------------------------------------------------------------------------
# WeightedSampleError                       Traceback (most recent call last)
# <ipython-input-4-f049a37241fb> in <module>
#       3 roots = ['chfinal']
#       4 pairs = [['omegam', 'H0']]
# ----> 5 g.plots_2d(roots, param_pairs=pairs, filled=True, shaded=False)
#       6 g.export()
#
# ~/anaconda2/envs/py37forge/lib/python3.7/site-packages/getdist/plots.py in plots_2d(self, roots, param1, params2, param_pairs, nx, legend_labels, legend_ncol, label_order, filled, shaded, **kwargs)
#    2107         else:
#    2108             for pair in param_pairs:
# -> 2109                 pairs.append((self._check_param(roots[0], pair[0]), self._check_param(roots[0], pair[1])))
#    2110         if filled and shaded:
#    2111             raise GetDistPlotError("Plots cannot be both filled and shaded")
#
# ~/anaconda2/envs/py37forge/lib/python3.7/site-packages/getdist/plots.py in _check_param(self, root, param, renames)
#    1781             name = param
#    1782         # NB: If a parameter is not found, errors only if param is a ParamInfo instance
# -> 1783         return self.param_names_for_root(root).parWithName(name, error=(name == param), renames=renames)
#    1784
#    1785     def param_latex_label(self, root, name, label_params=None):
#
# ~/anaconda2/envs/py37forge/lib/python3.7/site-packages/getdist/plots.py in param_names_for_root(self, root)
#     881         if root not in self.param_name_sets:
#     882             self.param_name_sets[root] = \
# --> 883                 self.sample_analyser.params_for_root(root, label_params=self.settings.param_names_for_labels)
#     884         return self.param_name_sets[root]
#     885
#
# ~/anaconda2/envs/py37forge/lib/python3.7/site-packages/getdist/plots.py in params_for_root(self, root, label_params)
#     618             names = root.paramNames
#     619         else:
# --> 620             samples = self.samples_for_root(root)
#     621             names = samples.getParamNames()
#     622         if label_params is not None:
#
# ~/anaconda2/envs/py37forge/lib/python3.7/site-packages/getdist/plots.py in samples_for_root(self, root, file_root, cache, settings)
#     503             if settings:
#     504                 dist_settings.update(settings)
# --> 505         self.mcsamples[root] = loadMCSamples(file_root, self.ini, job_item, settings=dist_settings)
#     506         return self.mcsamples[root]
#     507
#
# ~/anaconda2/envs/py37forge/lib/python3.7/site-packages/getdist/mcsamples.py in loadMCSamples(file_root, ini, jobItem, no_cache, settings)
#     101     if not len(files):
#     102         raise IOError('No chains found: ' + file_root)
# --> 103     samples.readChains(files)
#     104     samples.savePickle(cachefile)
#     105     return samples
#
# ~/anaconda2/envs/py37forge/lib/python3.7/site-packages/getdist/mcsamples.py in readChains(self, files_or_samples, weights, loglikes)
#     537             self.makeSingle()
#     538
# --> 539         self.updateBaseStatistics()
#     540
#     541         return self
#
# ~/anaconda2/envs/py37forge/lib/python3.7/site-packages/getdist/mcsamples.py in updateBaseStatistics(self)
#     547         :return: self
#     548         """
# --> 549         super(MCSamples, self).updateBaseStatistics()
#     550         mult_max = (self.mean_mult * self.numrows) / min(self.numrows // 2, 500)
#     551         outliers = np.sum(self.weights > mult_max)
#
# ~/anaconda2/envs/py37forge/lib/python3.7/site-packages/getdist/chains.py in updateBaseStatistics(self)
#    1137         self.mean_mult = self.norm / self.numrows
#    1138         self.max_mult = np.max(self.weights)
# -> 1139         self._getParamIndices()
#    1140         self.needs_update = False
#    1141         return self
#
# ~/anaconda2/envs/py37forge/lib/python3.7/site-packages/getdist/chains.py in _getParamIndices(self)
#    1032         """
#    1033         if self.samples is not None and len(self.paramNames.names) != self.n:
# -> 1034             raise WeightedSampleError("paramNames size does not match number of parameters in samples")
#    1035         index = dict()
#    1036         for i, name in enumerate(self.paramNames.names):
#
# WeightedSampleError: paramNames size does not match number of parameters in samples

# %%
#load sne
import numpy as np
Num_chains=4
matlist=[]
burnin=0.1
dirname=r'/home/nayantara/Desktop/Cosmology_Dvorkin/Project_Cosmology/Cosmo212/Results_JLA/FL2/'
for ch in range(Num_chains):
    itns = np.loadtxt(dirname+'chfinal_'+str(ch)+'.txt')
    start = int(itns.shape[0] * burnin)
    itns=itns[start:, :] #remove burnin
    itns[:, 1]=itns[:, 1]*100 #h->H0
    num_samp=itns.shape[0]
    matlist.append(np.hstack([np.ones(num_samp).reshape(-1,1), np.zeros(num_samp).reshape(-1, 1), itns]))
mat=np.vstack(matlist)
print( mat.shape)
# Out:
# (720000, 4)

# %%
np.savetxt(r'/home/nayantara/Desktop/Cosmology_Dvorkin/Project_Cosmology/Datasets/Combined chains/chains_FL2/ch_final.txt', mat)

# %%
mat[:, 1] = mat[:, 1]*100
names=['omegam', 'H0']
labels=['\Omega_m', 'H_0']
samp_sne=MCSamples(samples=mat, names = names, labels = labels)
# Out:
# Removed no burn in

# %%
samp_Planck=MCSamples(root=r'/home/nayantara/Desktop/Cosmology_Dvorkin/Project_Cosmology/Datasets/Combined chains/chains_FL2/base_plikHM_TTTEEE_lowl_lowE_lensing')
print (samp_Planck.paramNames)

# %%
# Filled 2D comparison plot with legend
g = plots.get_single_plotter(width_inch=4, ratio=1)
g.plot_2d([samp_Planck, samp_sne], 'omegam', 'H0', filled=True)
g.add_legend(['Planck', 'JLA'], colored_text=True);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-3c4f86c0bfb3> in <module>
#       1 # Filled 2D comparison plot with legend
#       2 g = plots.get_single_plotter(width_inch=4, ratio=1)
# ----> 3 g.plot_2d([samp_Planck, samp_sne], 'omegam', 'H0', filled=True)
#       4 g.add_legend(['Planck', 'JLA'], colored_text=True);
#
# ~/anaconda2/envs/py37forge/lib/python3.7/site-packages/getdist/plots.py in plot_2d(self, roots, param1, param2, param_pair, shaded, add_legend_proxy, line_offset, proxy_root_exclude, ax, **kwargs)
#    1646             res = self.add_2d_contours(root, param_pair[0], param_pair[1], line_offset + i, of=len(roots), ax=ax,
#    1647                                        add_legend_proxy=add_legend_proxy and root not in proxy_root_exclude,
# -> 1648                                        **contour_args[i])
#    1649             xbounds, ybounds = self._update_limits(res, xbounds, ybounds)
#    1650         if xbounds is None:
#
# ~/anaconda2/envs/py37forge/lib/python3.7/site-packages/getdist/plots.py in add_2d_contours(self, root, param1, param2, plotno, of, cols, contour_levels, add_legend_proxy, param_pair, density, alpha, ax, **kwargs)
#    1030                 density = self.sample_analyser.get_density_grid(root, param1, param2,
#    1031                                                                 conts=self.settings.num_plot_contours,
# -> 1032                                                                 likes=self.settings.shade_meanlikes)
#    1033             if density is None:
#    1034                 if add_legend_proxy:
#
# ~/anaconda2/envs/py37forge/lib/python3.7/site-packages/getdist/plots.py in get_density_grid(self, root, param1, param2, conts, likes)
#     589         if not density:
#     590             samples = self.samples_for_root(root)
# --> 591             density = samples.get2DDensityGridData(param1.name, param2.name, num_plot_contours=conts, meanlikes=likes)
#     592             if density is None:
#     593                 return None
#
# ~/anaconda2/envs/py37forge/lib/python3.7/site-packages/getdist/mcsamples.py in get2DDensityGridData(self, j, j2, num_plot_contours, get_density, meanlikes, **kwargs)
#    1654         """
#    1655         if self.needs_update:
# -> 1656             self.updateBaseStatistics()
#    1657         start = time.time()
#    1658         j, parx = self._parAndNumber(j)
#
# ~/anaconda2/envs/py37forge/lib/python3.7/site-packages/getdist/mcsamples.py in updateBaseStatistics(self)
#     547         :return: self
#     548         """
# --> 549         super(MCSamples, self).updateBaseStatistics()
#     550         mult_max = (self.mean_mult * self.numrows) / min(self.numrows // 2, 500)
#     551         outliers = np.sum(self.weights > mult_max)
#
# ~/anaconda2/envs/py37forge/lib/python3.7/site-packages/getdist/chains.py in updateBaseStatistics(self)
#    1134         :return: self after updating statistics.
#    1135         """
# -> 1136         self.getVars()
#    1137         self.mean_mult = self.norm / self.numrows
#    1138         self.max_mult = np.max(self.weights)
#
# ~/anaconda2/envs/py37forge/lib/python3.7/site-packages/getdist/chains.py in getVars(self)
#     375         :return: A numpy array of variances.
#     376         """
# --> 377         if self.means is None: self.setMeans()
#     378         self.vars = np.empty(self.n)
#     379         for i in range(self.n):
#
# ~/anaconda2/envs/py37forge/lib/python3.7/site-packages/getdist/chains.py in setMeans(self)
#     348         :return: numpy array of parameter means
#     349         """
# --> 350         self.means = self.weights.dot(self.samples) / self.norm
#     351         if self.loglikes is not None:
#     352             self.mean_loglike = self.weights.dot(self.loglikes) / self.norm
#
# AttributeError: 'NoneType' object has no attribute 'dot'

# %%
import numpy as np
